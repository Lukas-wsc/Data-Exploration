# %%
import numpy as np # for array, linear algebra
import pandas as pd # for data processing
import matplotlib.pyplot as plt # to crreate stat and visualize data
import matplotlib as mpl  # to visualize data
import seaborn as sns # to visualize data
import matplotlib.colors as mcolors # to visualize colors
import string # collection of alphabets, words or other characters
import re # regular expression support
import nltk 
from nltk.corpus import stopwords
from string import punctuation 
# import gensim # representing documents as semantic vectors

from nltk.tokenize import word_tokenize
from nltk.classify import NaiveBayesClassifier
from nltk.classify.util import accuracy

# %%
pd.set_option('display.max_colwidth', None)

# %%
df_naive_bayes_with_stopwords = pd.read_csv('../../Data-Pretraindata_without_stopwords.csv')

# %% [markdown]
# ### Create a new column 'Ground_Truth_Label' based on the 'target' values

# %%
def map_target_to_label(target):
    if target == 4:
        return 'positive'
    elif target == 0:
        return 'negative'
    else:
        return None

# %%
df_naive_bayes_with_stopwords['Ground_Truth_Label'] = df_naive_bayes_with_stopwords['target'].apply(map_target_to_label)

# %%
df_naive_bayes_with_stopwords
# Out:
#          target  \
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1599995       4
# 1599996       4
# 1599997       4
# 1599998       4
# 1599999       4
#
#                                                                           Text  \
# 0                                 Awww bummer shoulda got David Carr Third Day
# 1        upset update Facebook texting might cry result School today also Blah
# 2                         dived many times ball Managed save 50 rest go bounds
# 3                                             whole body feels itchy like fire
# 4                                                             behaving mad see
# ...                                                                        ...
# 1599995                                          woke school best feeling ever
# 1599996                             TheWDB com cool hear old Walt interviews ♫
# 1599997                                        ready MoJo Makeover Ask details
# 1599998                   Happy 38th Birthday boo alll time Tupac Amaru Shakur
# 1599999                                                                  happy
#
#         Ground_Truth_Label
# 0                 negative
# 1                 negative
# 2                 negative
# 3                 negative
# 4                 negative
# ...                    ...
# 1599995           positive
# 1599996           positive
# 1599997           positive
# 1599998           positive
# 1599999           positive
#
# [1600000 rows x 3 columns]

# %%
df_naive_bayes_with_stopwords['target'].value_counts()
# Out:
# target
# 0    800000
# 4    800000
# Name: count, dtype: int64

# %%
df_naive_bayes_with_stopwords
# Out:
#          target  \
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1599995       4
# 1599996       4
# 1599997       4
# 1599998       4
# 1599999       4
#
#                                                                           Text  \
# 0                                 Awww bummer shoulda got David Carr Third Day
# 1        upset update Facebook texting might cry result School today also Blah
# 2                         dived many times ball Managed save 50 rest go bounds
# 3                                             whole body feels itchy like fire
# 4                                                             behaving mad see
# ...                                                                        ...
# 1599995                                          woke school best feeling ever
# 1599996                             TheWDB com cool hear old Walt interviews ♫
# 1599997                                        ready MoJo Makeover Ask details
# 1599998                   Happy 38th Birthday boo alll time Tupac Amaru Shakur
# 1599999                                                                  happy
#
#         Ground_Truth_Label
# 0                 negative
# 1                 negative
# 2                 negative
# 3                 negative
# 4                 negative
# ...                    ...
# 1599995           positive
# 1599996           positive
# 1599997           positive
# 1599998           positive
# 1599999           positive
#
# [1600000 rows x 3 columns]

# %%
def extract_features(text):
    words = word_tokenize(text)
    features = {word.lower(): True for word in words if word.isalpha()}
    return features

# %%
df_naive_bayes_with_stopwords['features'] = df_naive_bayes_with_stopwords['Text'].apply(extract_features)

# %%
data = list(zip(df_naive_bayes_with_stopwords['features'], df_naive_bayes_with_stopwords['Ground_Truth_Label']))

# %%
classifier = NaiveBayesClassifier.train(data)

# %%
df_naive_bayes_with_stopwords
# Out:
#          target  \
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1599995       4
# 1599996       4
# 1599997       4
# 1599998       4
# 1599999       4
#
#                                                                           Text  \
# 0                                 Awww bummer shoulda got David Carr Third Day
# 1        upset update Facebook texting might cry result School today also Blah
# 2                         dived many times ball Managed save 50 rest go bounds
# 3                                             whole body feels itchy like fire
# 4                                                             behaving mad see
# ...                                                                        ...
# 1599995                                          woke school best feeling ever
# 1599996                             TheWDB com cool hear old Walt interviews ♫
# 1599997                                        ready MoJo Makeover Ask details
# 1599998                   Happy 38th Birthday boo alll time Tupac Amaru Shakur
# 1599999                                                                  happy
#
#         Ground_Truth_Label  \
# 0                 negative
# 1                 negative
# 2                 negative
# 3                 negative
# 4                 negative
# ...                    ...
# 1599995           positive
# 1599996           positive
# 1599997           positive
# 1599998           positive
# 1599999           positive
#
#                                                                                                                                                                           features
# 0                                                            {'awww': True, 'bummer': True, 'shoulda': True, 'got': True, 'david': True, 'carr': True, 'third': True, 'day': True}
# 1        {'upset': True, 'update': True, 'facebook': True, 'texting': True, 'might': True, 'cry': True, 'result': True, 'school': True, 'today': True, 'also': True, 'blah': True}
# 2                                              {'dived': True, 'many': True, 'times': True, 'ball': True, 'managed': True, 'save': True, 'rest': True, 'go': True, 'bounds': True}
# 3                                                                                          {'whole': True, 'body': True, 'feels': True, 'itchy': True, 'like': True, 'fire': True}
# 4                                                                                                                                     {'behaving': True, 'mad': True, 'see': True}
# ...                                                                                                                                                                            ...
# 1599995                                                                                                {'woke': True, 'school': True, 'best': True, 'feeling': True, 'ever': True}
# 1599996                                                                   {'thewdb': True, 'com': True, 'cool': True, 'hear': True, 'old': True, 'walt': True, 'interviews': True}
# 1599997                                                                                              {'ready': True, 'mojo': True, 'makeover': True, 'ask': True, 'details': True}
# 1599998                                                   {'happy': True, 'birthday': True, 'boo': True, 'alll': True, 'time': True, 'tupac': True, 'amaru': True, 'shakur': True}
# 1599999                                                                                                                                                            {'happy': True}
#
# [1600000 rows x 4 columns]

# %%
print(f'Accuracy: {accuracy(classifier, data):.2f}')
# Out:
# Accuracy: 0.79

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#             tweeteradder = True           positi : negati =    553.7 : 1.0
#              shareholder = True           positi : negati =     53.0 : 1.0
#                     sadd = True           negati : positi =     43.4 : 1.0
#                   triste = True           negati : positi =     42.3 : 1.0
#                   farrah = True           negati : positi =     41.1 : 1.0
#                  saddens = True           negati : positi =     41.0 : 1.0
#                 fuzzball = True           positi : negati =     39.8 : 1.0
#                  whyyyyy = True           negati : positi =     37.7 : 1.0
#                  eddings = True           negati : positi =     36.3 : 1.0
#                  sadface = True           negati : positi =     36.1 : 1.0
